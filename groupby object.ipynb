# %%
import pandas as pd

# %%
fortune=pd.read_csv('fortune1000.csv',index_col='Rank')
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors=fortune.groupby('Sector')
sectors

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# # groupby method

# %%
len(fortune)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
fortune['Sector'].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune.Sector.value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Apparel                          15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
sectors.first()   #----extract first row of each sectors
sectors.last()    #----extract last row of each sectors
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
fortune.loc[155]
# Out:
# Company                           Fluor
# Sector       Engineering & Construction
# Industry      Engineering, Construction
# Location                     Irving, TX
# Revenue                           18114
# Profits                             413
# Employees                         38758
# Name: 155, dtype: object

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [24, 45, 60, 88, 118, 120, 209, 245, 282, 378, 389, 490, 560, 605, 785, 788, 836, 903, 958, 987], 'Apparel': [91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877, 882, 917], 'Business Services': [144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404, 440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694, 714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796, 801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993], 'Chemicals': [56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549, 555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829, 865, 898, 934, 949], 'Energy': [2, 14, 30, 32, 42, 65, 90, 95, 98, 104, 115, 117, 121, 162, 163, 165, 166, 175, 178, 188, 190, 192, 193, 198, 214, 216, 217, 223, 225, 229, 243, 246, 247, 257, 272, 274, 279, 289, 319, 322, 324, 343, 348, 349, 350, 363, 364, 384, 387, 388, 394, 402, 403, 410, 425, 437, 438, 445, 458, 475, 483, 493, 507, 522, 541, 548, 556, 558, 569, 5
# ...

# %% [markdown]
# # retrieve a group with the get_group method

# %%
sectors.get_group('Telecommunications')
# Out:
#                          Company              Sector            Industry  \
# Rank
# 10                          AT&T  Telecommunications  Telecommunications
# 13                       Verizon  Telecommunications  Telecommunications
# 37                       Comcast  Telecommunications  Telecommunications
# 116            Time Warner Cable  Telecommunications  Telecommunications
# 159                  CenturyLink  Telecommunications  Telecommunications
# 187                 DISH Network  Telecommunications  Telecommunications
# 292       Charter Communications  Telecommunications  Telecommunications
# 333       Level 3 Communications  Telecommunications  Telecommunications
# 399          Cablevision Systems  Telecommunications  Telecommunications
# 443          Windstream Holdings  Telecommunications  Telecommunications
# 461      Frontier Communications  Telecommunications  Telecommunications
# 496     Telephone & Data Systems  Telecommunications  Telecommunications
# ...

# %%
fortune[fortune['Sector']=='Telecommunications']  #---another way
# Out:
#                          Company              Sector            Industry  \
# Rank
# 10                          AT&T  Telecommunications  Telecommunications
# 13                       Verizon  Telecommunications  Telecommunications
# 37                       Comcast  Telecommunications  Telecommunications
# 116            Time Warner Cable  Telecommunications  Telecommunications
# 159                  CenturyLink  Telecommunications  Telecommunications
# 187                 DISH Network  Telecommunications  Telecommunications
# 292       Charter Communications  Telecommunications  Telecommunications
# 333       Level 3 Communications  Telecommunications  Telecommunications
# 399          Cablevision Systems  Telecommunications  Telecommunications
# 443          Windstream Holdings  Telecommunications  Telecommunications
# 461      Frontier Communications  Telecommunications  Telecommunications
# 496     Telephone & Data Systems  Telecommunications  Telecommunications
# ...

# %% [markdown]
# # methods of groupby object and df columns

# %%
sectors.max()   #----get the max value based on the company column where woodward appears last 
sectors.min()   #----get the min value based on the company column where B/E Aerospace appears first
# Out:
#                                                     Company  \
# Sector
# Aerospace & Defense                           B/E Aerospace
# Apparel                                            Carter’s
# Business Services                            ABM Industries
# Chemicals                                       A. Schulman
# Energy                                                  AES
# Engineering & Construction                            AECOM
# Financials                                              AIG
# Food and Drug Stores                             CVS Health
# Food, Beverages & Tobacco        Alliance One International
# Health Care                                          AbbVie
# Hotels, Resturants & Leisure                Bloomin’ Brands
# Household Products                            Avon Products
# Industrials                                              3M
# Materials                            A-Mark Precious Metals
# ...

# %%
sectors.sum()
sectors.mean()
# Out:
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/3065099060.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.sum()
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/3065099060.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.mean()
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# ...

# %%
sectors.get_group('Apparel')['Revenue'].sum()
# Out:
# 95968

# %%
sectors['Revenue'].sum()
sectors['Profits'].max()
sectors['Profits'].min()
sectors['Employees'].sum()

sectors[['Revenue','Profits']].sum()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940    28742
# Apparel                         95968     8236
# Business Services              272195    28227
# Chemicals                      243897    22628
# Energy                        1517809   -73447
# Engineering & Construction     153983     5304
# Financials                    2217159   260209
# Food and Drug Stores           483769    16759
# Food, Beverages & Tobacco      555967    51417
# Health Care                   1614707   106114
# Hotels, Resturants & Leisure   169546    20697
# Household Products             234737    14428
# Industrials                    497581    20764
# Materials                      259145     4428
# Media                          220764    24347
# Motor Vehicles & Parts         482540    25898
# Retailing                     1465076    47830
# Technology                    1377600   180473
# Telecommunications             461834    48637
# ...

# %% [markdown]
# # grouping by multiple columns

# %%
sectors=fortune.groupby(['Sector','Industry'])
sectors.head(3)
# Out:
#                      Company              Sector  \
# Rank
# 1                    Walmart           Retailing
# 2                Exxon Mobil              Energy
# 3                      Apple          Technology
# 4         Berkshire Hathaway          Financials
# 5                   McKesson         Health Care
# ...                      ...                 ...
# 820   Apollo Education Group   Business Services
# 870           Public Storage   Business Services
# 930                    Kirby      Transportation
# 950            Vista Outdoor  Household Products
# 993    DeVry Education Group   Business Services
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# ...

# %%
sectors.size()
sectors.sum()
# Out:
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2906017963.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sectors.sum()
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# ...

# %%
sectors['Revenue'].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            357940
# Apparel              Apparel                                           95968
# Business Services    Advertising, marketing                            22748
#                      Diversified Outsourcing Services                  64829
#                      Education                                          7485
#                                                                        ...
# Transportation       Trucking, Truck Leasing                           35950
# Wholesalers          Miscellaneous                                      8982
#                      Wholesalers: Diversified                         176138
#                      Wholesalers: Electronics and Office Equipment    147906
#                      Wholesalers: Food and Grocery                    111774
# Name: Revenue, Length: 79, dtype: int64

# %% [markdown]
# # agg method

# %%
fortune=pd.read_csv('fortune1000.csv',index_col='Rank')
sectors=fortune.groupby('Sector')
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.agg({'Revenue':['sum','mean'],
            'Profits':'sum',
            'Employees':'mean'})
# Out:
#                               Revenue               Profits     Employees
#                                   sum          mean     sum          mean
# Sector
# Aerospace & Defense            357940  17897.000000   28742  48402.850000
# Apparel                         95968   6397.866667    8236  23093.133333
# Business Services              272195   5337.156863   28227  26687.254902
# Chemicals                      243897   8129.900000   22628  15455.033333
# Energy                        1517809  12441.057377  -73447   9745.303279
# Engineering & Construction     153983   5922.423077    5304  15642.615385
# Financials                    2217159  15950.784173  260209  24172.287770
# Food and Drug Stores           483769  32251.266667   16759  93026.533333
# Food, Beverages & Tobacco      555967  12929.465116   51417  28177.488372
# Health Care                   1614707  21529.426667  106114  35710.520000
# Hotels, Resturants & Leisure   169546   6781.840000   20697  99369.800000
# ...

# %%
sectors.agg(['size','sum','mean'])
# Out:
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2748255897.py:1: FutureWarning: ['Company', 'Industry', 'Location'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   sectors.agg(['size','sum','mean'])
#                              Revenue                        Profits          \
#                                 size      sum          mean    size     sum
# Sector
# Aerospace & Defense               20   357940  17897.000000      20   28742
# Apparel                           15    95968   6397.866667      15    8236
# Business Services                 51   272195   5337.156863      51   28227
# Chemicals                         30   243897   8129.900000      30   22628
# Energy                           122  1517809  12441.057377     122  -73447
# Engineering & Construction        26   153983   5922.423077      26    5304
# ...

# %% [markdown]
# # iterating through groups

# %%
sectors['Revenue'].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
df=pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector ,data in sectors:
    highest_revenue_company_in_group=data.nlargest(1,'Revenue')
    df=df.append(highest_revenue_company_in_group)
# Out:
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2526909025.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(highest_revenue_company_in_group)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2526909025.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(highest_revenue_company_in_group)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2526909025.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(highest_revenue_company_in_group)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/2526909025.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
cities=fortune.groupby('Location')
df1=pd.DataFrame(columns=fortune.columns)
df1
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
cities['Revenue'].max()
# Out:
# Location
# Abbott Park, IL     20661
# Akron, OH           16443
# Allentown, PA        9895
# Angleton, TX         2541
# Ankeny, IA           7052
#                     ...
# Woonsocket, RI     153290
# Worcester, MA        5034
# Wyomissing, PA       2838
# York, PA             2790
# Zeeland, MI          2142
# Name: Revenue, Length: 416, dtype: int64

# %%
for city ,data in cities:
    highest_revenue_in_city=data.nlargest(1,'Revenue')
    df1=df1.append(highest_revenue_in_city)
# Out:
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/475981170.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(highest_revenue_in_city)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/475981170.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(highest_revenue_in_city)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/475981170.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(highest_revenue_in_city)
# C:\Users\subha\AppData\Local\Temp/ipykernel_4812/475981170.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1=df1.append(highest_revenue_in_city)
# ...

# %%
df1
# Out:
#                       Company                        Sector  \
# 138       Abbott Laboratories                   Health Care
# 169    Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288  Air Products & Chemicals                     Chemicals
# 830     Benchmark Electronics                    Technology
# 374    Casey’s General Stores                     Retailing
# ..                        ...                           ...
# 7                  CVS Health          Food and Drug Stores
# 506   Hanover Insurance Group                    Financials
# 764      Penn National Gaming  Hotels, Resturants & Leisure
# 773            Bon-Ton Stores                     Retailing
# 932             Herman Miller            Household Products
#
#                                            Industry         Location Revenue  \
# 138                  Medical Products and Equipment  Abbott Park, IL   20661
# 169                        Motor Vehicles and Parts        Akron, OH   16443
# ...
